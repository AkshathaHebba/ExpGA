# %% [markdown]
# # Pre-Requesites Installation

# %%
# Install the Spacy Dependencies.
import sys
# !{sys.executable} -m pip install -U pip setuptools wheel
# !{sys.executable} -m pip install -U spacy
# !{sys.executable} -m pip install -U nltk
# !{sys.executable} -m pip install -U pandas
from spacy import displacy
# !{sys.executable} -m pip install -U numpy
# Out:
# Requirement already satisfied: pip in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (22.3.1)
# Requirement already satisfied: setuptools in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (65.6.3)
# Requirement already satisfied: wheel in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (0.38.4)
# Requirement already satisfied: spacy in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (3.4.4)
# Requirement already satisfied: pathy>=0.3.5 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.24.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (8.1.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: setuptools in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: packaging>=20.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Requirement already satisfied: nltk in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (3.8)
# Requirement already satisfied: joblib in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: pandas in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.24.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/akshathahebbar/opt/anaconda3/lib/python3.9/site-packages (1.24.0)

# %%
# Download the Spacy model.
# !{sys.executable} -m spacy download en_core_web_trf
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting en-core-web-trf==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.4.1/en_core_web_trf-3.4.1-py3-none-any.whl (460.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.3/460.3 MB 7.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from en-core-web-trf==3.4.1) (3.4.4)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from en-core-web-trf==3.4.1) (1.1.9)
# Requirement already satisfied: numpy>=1.15.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (1.23.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (1.10.2)
# Requirement already satisfied: pathy>=0.3.5 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (4.64.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (22.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.0.7)
# Requirement already satisfied: setuptools in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (65.6.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (1.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.4.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (8.1.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.28.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (3.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (3.0.8)
# Requirement already satisfied: torch>=1.6.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (1.13.1)
# Requirement already satisfied: transformers<4.26.0,>=3.4.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (4.25.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (0.7.9)
# Requirement already satisfied: regex!=2019.12.17 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (0.11.1)
# Requirement already satisfied: filelock in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (3.8.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->en-core-web-trf==3.4.1) (6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jinja2->spacy<3.5.0,>=3.4.1->en-core-web-trf==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: jinja2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (22.0)
# Requirement already satisfied: numpy>=1.15.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.23.5)
# Requirement already satisfied: setuptools in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (65.6.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Rule-Based Matching Using Spacy

# %% [markdown]
# ![hearst_patterns-768x435.png](attachment:hearst_patterns-768x435.png)
#
# The simple rule-based methods work well for information extraction tasks.
#
# We have to be extremely creative to come up with new rules to capture different patterns. It is difficult to build patterns that generalize well across different sentences.

# %%
import re 
import string 
import nltk 
import spacy 
import pandas as pd 
import numpy as np 
import math 
from tqdm import tqdm 

from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy 

pd.set_option('display.max_colwidth', 200)

# load spaCy model
nlp = spacy.load("en_core_web_trf")

# sample text 
# text =  "GDP in developing countries such as Vietnam will continue growing at a high rate." 
# text =  "Here is how you can keep your car and other vehicles clean."
# text = "Eight people, including two children, were injured in the explosion"
# text = "A healthy eating pattern includes fruits, especially whole fruits."
text = "Tableau was recently acquired by Salesforce." 

# create a spaCy object 
doc = nlp(text)

# print token, dependency, POS tag 
for tok in doc: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)


#mine information from text based on these Hearst Patterns.
#define the pattern 
## Have a look around the terms “such” and “as” . 
#Pattern: X such as Y
pattern = [
           {'DEP':'amod', 'OP':"?"}, # adjectival modifier
           {'POS':'NOUN'}, 
           {'LOWER': 'such'}, 
           {'LOWER': 'as'}, 
           {'POS': 'PROPN'}] #proper noun
# Pattern: X and/or Y
pattern2 = [{'DEP':'amod', 'OP':"?"}, 
           {'POS':'NOUN'}, 
           {'LOWER': 'and', 'OP':"?"}, 
           {'LOWER': 'or', 'OP':"?"}, 
           {'LOWER': 'other'}, 
           {'POS': 'NOUN'}]
# Pattern: X, including Y
pattern3 = [{'DEP':'nummod','OP':"?"}, # numeric modifier 
           {'DEP':'amod','OP':"?"}, # adjectival modifier 
           {'POS':'NOUN'}, 
           {'IS_PUNCT': True}, 
           {'LOWER': 'including'}, 
           {'DEP':'nummod','OP':"?"}, 
           {'DEP':'amod','OP':"?"}, 
           {'POS':'NOUN'}]
# Pattern: X, especially Y
pattern4 = [{'DEP':'nummod','OP':"?"}, 
           {'DEP':'amod','OP':"?"}, 
           {'POS':'NOUN'}, 
           {'IS_PUNCT':True}, 
           {'LOWER': 'especially'}, 
           {'DEP':'nummod','OP':"?"}, 
           {'DEP':'amod','OP':"?"}, 
           {'POS':'NOUN'}] 

pd.set_option('display.max_colwidth', 200)

# Matcher class object 
matcher = Matcher(nlp.vocab) 
matcher.add("matching_1", [pattern, pattern2, pattern3, pattern4]) 

matches = matcher(doc)
if(matches):
    span = doc[matches[0][1]:matches[0][2]]
    print('The Pattern found in the statement is......')
    print(span.text)
else:
    print('no patterns matched the statement.....')
# Out:
# Tableau --> nsubjpass --> PROPN
# was --> auxpass --> AUX
# recently --> advmod --> ADV
# acquired --> ROOT --> VERB
# by --> agent --> ADP
# Salesforce --> pobj --> PROPN
# . --> punct --> PUNCT
# no patterns matched the statement.....

# %% [markdown]
# # Subtree Matching for Relation Extraction

# %%
def subtree_matcher(doc):
  subjpass = 0

  for i,tok in enumerate(doc):
    # find dependency tag that contains the text "subjpass"    
    if tok.dep_.find("subjpass") == True:
      subjpass = 1

  x = ''
  y = ''
  verb = ''

  # if subjpass == 1 then sentence is passive
  if subjpass == 1:
    for i,tok in enumerate(doc):
      if tok.dep_.find("subjpass") == True:
        y = tok.text
      if tok.dep_.endswith("obj") == True:
        x = tok.text
        
      
  
  # if subjpass == 0 then sentence is not passive
  else:
    for i,tok in enumerate(doc):
      if tok.dep_.endswith("subj") == True:
        x = tok.text

      if tok.dep_.endswith("obj") == True:
        y = tok.text

  return x,y

# %%
text_2 = "Careem, a ride hailing major in middle east, was acquired by Uber." 

doc_2 = nlp(text_2) 
subtree_matcher(doc_2)
# Out:
# ('Uber', 'Careem')

# %%
text_3 = "Salesforce recently acquired Tableau." 
doc_3 = nlp(text_3) 
subtree_matcher(doc_3)
# Out:
# ('Salesforce', 'Tableau')

# %%
text_3 = "Tableau was recently acquired by Salesforce." 
doc_3 = nlp(text_3) 
subtree_matcher(doc_3)
# Out:
# ('Salesforce', 'Tableau')

# %% [markdown]
# # Knowledge Graph

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
